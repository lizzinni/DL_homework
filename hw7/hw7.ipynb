# %%
import random
import time
from tqdm import tqdm

import torch
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
MODEL_NAME = "google/flan-t5-small"
AG_LABELS = ["World", "Sports", "Business", "Sci/Tech"]
FEW_SHOT_K = 3
ONE_SHOT_K = 1
MAX_TEST_EXAMPLES = 500
GEN_MAX_LENGTH = 50  # модель вернёт короткий ответ (несколько токенов)
GEN_TEMPERATURE = 0.0  # детерминированный вывод
GEN_NUM_BEAMS = 1  # жадный поиск

# Пауза между запросами (чтобы не перегрузить cpu)
PAUSE_BETWEEN_CALLS = 0.1

# %%
print("Загружаем AG News из Hugging Face Datasets...")
dataset = load_dataset("ag_news")

train_ds = dataset["train"]
test_ds = dataset["test"]

print(f"Размер train: {len(train_ds)} статей")
print(f"Размер test : {len(test_ds)} статей")
# Out:
# Загружаем AG News из Hugging Face Datasets...
# Размер train: 120000 статей
# Размер test : 7600 статей

# %%
# Перемешаем train и выберем FEW_SHOT_K примеров для подсказок (они не будут участвовать в оценке)
indices = list(range(len(train_ds)))
random.shuffle(indices)

few_shot_indices = indices[:FEW_SHOT_K]
few_shot_examples = [train_ds[i] for i in few_shot_indices]

# В качестве one-shot возьмём первые ONE_SHOT_K из few-shot
one_shot_examples = few_shot_examples[:ONE_SHOT_K]

print(f"\nfew-shot ({FEW_SHOT_K} примеров) взято из train:")
for ex in few_shot_examples:
    lbl = AG_LABELS[ex["label"]]
    print(f"  • [{lbl}] {ex['text'][:60].strip()}...")

print(f"\none-shot (1 пример) — первый из few-shot: [{AG_LABELS[one_shot_examples[0]['label']]}] "
      f"{one_shot_examples[0]['text'][:60].strip()}...")
print()
# Out:
# few-shot (3 примеров) взято из train:
#   • [Sci/Tech] List of 2004 MacArthur Foundation Fellows (AP) AP - The list...
#   • [Business] MG Rover to slash directors #39; pension payments by 90 MG R...
#   • [Sports] Hawk one-ups himself It turns out Richard Awa was just warmi...
#
# one-shot (1 пример) — первый из few-shot: [Sci/Tech] List of 2004 MacArthur Foundation Fellows (AP) AP - The list...

# %%
print(f"Загружаем модель и токенизатор {MODEL_NAME}...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)

device = torch.device("cpu")
model.to(device)
model.eval()
print("Модель загружена и переключена на CPU.\n")
# Out:
# Загружаем модель и токенизатор google/flan-t5-small...
# Модель загружена и переключена на CPU.

# %%
def build_prompt_zero(text: str) -> str:  # для формирования zero-shot подсказки. Даем инструкцию + текст статьи и поясняем, что хотим получить метку
    instruction = (
        "Classify the following news article into one of the categories: "
        + ", ".join(AG_LABELS)
        + ".\n"
    )
    prompt = (
        instruction
        + "Article:\n\"\"\"\n"
        + text.strip()
        + "\n\"\"\"\n"
        + "Category:"
    )
    return prompt

def build_prompt_one(text: str, one_example: dict) -> str:  # для формирования one-shot подсказки, даем инструкцию + один пример + текст и просим метку
    instruction = (
        "Classify the following news article into one of the categories: "
        + ", ".join(AG_LABELS)
        + ".\n"
    )
    example_text = one_example["text"].strip()
    example_label = AG_LABELS[one_example["label"]]
    prompt = (
        instruction
        + "Example:\n"
        + "Article:\n\"\"\"\n"
        + example_text
        + "\n\"\"\"\n"
        + "Category: "
        + example_label
        + "\n---\n"
        + "Now classify this article:\n"
        + "Article:\n\"\"\"\n"
        + text.strip()
        + "\n\"\"\"\n"
        + "Category:"
    )
    return prompt

def build_prompt_few(text: str, few_examples: list) -> str:  # для формирования few-shot подсказки, даем инструкцию + несколько примеров + новый текст и просим метку
    instruction = (
        "Classify the following news article into one of the categories: "
        + ", ".join(AG_LABELS)
        + ".\n"
    )
    prompt = instruction
    for ex in few_examples:
        ex_text = ex["text"].strip()
        ex_label = AG_LABELS[ex["label"]]
        prompt += (
            "Example:\n"
            + "Article:\n\"\"\"\n"
            + ex_text
            + "\n\"\"\"\n"
            + "Category: "
            + ex_label
            + "\n---\n"
        )
    prompt += (
        "Now classify this article:\n"
        + "Article:\n\"\"\"\n"
        + text.strip()
        + "\n\"\"\"\n"
        + "Category:"
    )
    return prompt

# %%
def classify_text(prompt: str) -> str:
    # Токенизируем ввод
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=512,
    ).to(device)

    # Генерируем ответ
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=GEN_MAX_LENGTH,
            temperature=GEN_TEMPERATURE,
            num_beams=GEN_NUM_BEAMS,
            early_stopping=True,
        )

    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()

    for lbl in AG_LABELS:
        if lbl.lower() in decoded.lower():
            return lbl
    return decoded

# %%
def run_mode(mode: str):
    assert mode in ["zero", "one", "few"], "mode must be one of 'zero', 'one', 'few'"

    predictions = []
    true_labels = []

    # Если нужно ограничить число примеров для быстрой проверки
    total = len(test_ds) if MAX_TEST_EXAMPLES is None else min(len(test_ds), MAX_TEST_EXAMPLES)
    print(f"\nЗапуск режима {mode}-shot на {total} примерах из test...")

    for idx in tqdm(range(total), desc=f"{mode}-shot classification"):
        ex = test_ds[idx]
        text = ex["text"]
        true_labels.append(AG_LABELS[ex["label"]])

        if mode == "zero":
            prompt = build_prompt_zero(text)
        elif mode == "one":
            prompt = build_prompt_one(text, one_shot_examples[0])
        else:  # mode == "few"
            prompt = build_prompt_few(text, few_shot_examples)

        pred = classify_text(prompt)
        predictions.append(pred)

        time.sleep(PAUSE_BETWEEN_CALLS)

    return true_labels, predictions

# %%
def compute_accuracy(y_true: list, y_pred: list) -> float:
    correct = sum(1 for yt, yp in zip(y_true, y_pred) if yt.lower() == yp.lower())
    return correct / len(y_true) if len(y_true) > 0 else 0.0

# %%
# Zero-shot
y_true_zero, y_pred_zero = run_mode("zero")
acc_zero = compute_accuracy(y_true_zero, y_pred_zero)
print(f"\nAccuracy (zero-shot): {acc_zero:.4f}")

# One-shot
y_true_one, y_pred_one = run_mode("one")
acc_one = compute_accuracy(y_true_one, y_pred_one)
print(f"\nAccuracy (one-shot): {acc_one:.4f}")

# Few-shot
y_true_few, y_pred_few = run_mode("few")
acc_few = compute_accuracy(y_true_few, y_pred_few)
print(f"\nAccuracy (few-shot): {acc_few:.4f}")

# Вариант: вывести несколько примеров с предсказаниями
print("\nПримеры (test) с предсказаниями (true -> pred) для few-shot:")
for i in range(min(5, len(y_true_few))):
    print(f"{i+1}. [{y_true_few[i]}] → [{y_pred_few[i]}]  |  {test_ds[i]['text'][:60].strip()}...")
# Out:
# Запуск режима zero-shot на 500 примерах из test...
# zero-shot classification:   0%|          | 0/500 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   0%|          | 1/500 [00:00<05:29,  1.51it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   0%|          | 2/500 [00:00<03:00,  2.76it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   1%|          | 3/500 [00:00<02:14,  3.68it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   1%|          | 4/500 [00:01<01:50,  4.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   1%|          | 5/500 [00:01<01:35,  5.18it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   1%|          | 6/500 [00:01<01:33,  5.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   1%|▏         | 7/500 [00:01<01:31,  5.40it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   2%|▏         | 8/500 [00:01<01:29,  5.48it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   2%|▏         | 9/500 [00:01<01:23,  5.88it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   2%|▏         | 10/500 [00:02<01:20,  6.10it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   2%|▏         | 11/500 [00:02<01:21,  6.02it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   2%|▏         | 12/500 [00:02<01:20,  6.05it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   3%|▎         | 13/500 [00:02<01:18,  6.24it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   3%|▎         | 14/500 [00:02<01:15,  6.40it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   3%|▎         | 15/500 [00:02<01:17,  6.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   3%|▎         | 16/500 [00:03<01:17,  6.24it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   3%|▎         | 17/500 [00:03<01:17,  6.20it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   4%|▎         | 18/500 [00:03<01:17,  6.20it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   4%|▍         | 19/500 [00:03<01:16,  6.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   4%|▍         | 20/500 [00:03<01:14,  6.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   4%|▍         | 21/500 [00:03<01:13,  6.56it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   4%|▍         | 22/500 [00:03<01:14,  6.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   5%|▍         | 23/500 [00:04<01:14,  6.42it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   5%|▍         | 24/500 [00:04<01:13,  6.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   5%|▌         | 25/500 [00:04<01:13,  6.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   5%|▌         | 26/500 [00:04<01:14,  6.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   5%|▌         | 27/500 [00:04<01:13,  6.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   6%|▌         | 28/500 [00:04<01:13,  6.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   6%|▌         | 29/500 [00:05<01:12,  6.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   6%|▌         | 30/500 [00:05<01:12,  6.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   6%|▌         | 31/500 [00:05<01:11,  6.53it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   6%|▋         | 32/500 [00:05<01:11,  6.54it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   7%|▋         | 33/500 [00:05<01:10,  6.58it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   7%|▋         | 34/500 [00:05<01:11,  6.54it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   7%|▋         | 35/500 [00:05<01:11,  6.52it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   7%|▋         | 36/500 [00:06<01:10,  6.54it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   7%|▋         | 37/500 [00:06<01:10,  6.59it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   8%|▊         | 38/500 [00:06<01:10,  6.59it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   8%|▊         | 39/500 [00:06<01:10,  6.58it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   8%|▊         | 40/500 [00:06<01:10,  6.56it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   8%|▊         | 41/500 [00:06<01:09,  6.58it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   8%|▊         | 42/500 [00:07<01:09,  6.55it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   9%|▊         | 43/500 [00:07<01:08,  6.64it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   9%|▉         | 44/500 [00:07<01:08,  6.67it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   9%|▉         | 45/500 [00:07<01:07,  6.72it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   9%|▉         | 46/500 [00:07<01:06,  6.80it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:   9%|▉         | 47/500 [00:07<01:07,  6.76it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  10%|▉         | 48/500 [00:07<01:06,  6.82it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  10%|▉         | 49/500 [00:08<01:06,  6.75it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  10%|█         | 50/500 [00:08<01:06,  6.81it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  10%|█         | 51/500 [00:08<01:06,  6.74it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  10%|█         | 52/500 [00:08<01:07,  6.66it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  11%|█         | 53/500 [00:08<01:07,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  11%|█         | 54/500 [00:08<01:07,  6.57it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  11%|█         | 55/500 [00:08<01:08,  6.51it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  11%|█         | 56/500 [00:09<01:09,  6.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  11%|█▏        | 57/500 [00:09<01:08,  6.50it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  12%|█▏        | 58/500 [00:09<01:07,  6.52it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  12%|█▏        | 59/500 [00:09<01:08,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  12%|█▏        | 60/500 [00:09<01:07,  6.52it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  12%|█▏        | 61/500 [00:09<01:06,  6.56it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  12%|█▏        | 62/500 [00:10<01:05,  6.68it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  13%|█▎        | 63/500 [00:10<01:06,  6.57it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  13%|█▎        | 64/500 [00:10<01:06,  6.59it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  13%|█▎        | 65/500 [00:10<01:05,  6.63it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  13%|█▎        | 66/500 [00:10<01:06,  6.51it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  13%|█▎        | 67/500 [00:10<01:06,  6.53it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  14%|█▎        | 68/500 [00:10<01:05,  6.63it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  14%|█▍        | 69/500 [00:11<01:03,  6.75it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  14%|█▍        | 70/500 [00:11<01:05,  6.52it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  14%|█▍        | 71/500 [00:11<01:07,  6.32it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  14%|█▍        | 72/500 [00:11<01:09,  6.12it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  15%|█▍        | 73/500 [00:11<01:07,  6.32it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  15%|█▍        | 74/500 [00:11<01:06,  6.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  15%|█▌        | 75/500 [00:12<01:05,  6.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  15%|█▌        | 76/500 [00:12<01:06,  6.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  15%|█▌        | 77/500 [00:12<01:06,  6.39it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  16%|█▌        | 78/500 [00:12<01:05,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  16%|█▌        | 79/500 [00:12<01:05,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  16%|█▌        | 80/500 [00:12<01:04,  6.55it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  16%|█▌        | 81/500 [00:12<01:04,  6.54it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  16%|█▋        | 82/500 [00:13<01:03,  6.58it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  17%|█▋        | 83/500 [00:13<01:03,  6.52it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  17%|█▋        | 84/500 [00:13<01:05,  6.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  17%|█▋        | 85/500 [00:13<01:03,  6.54it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  17%|█▋        | 86/500 [00:13<01:03,  6.51it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  17%|█▋        | 87/500 [00:13<01:03,  6.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  18%|█▊        | 88/500 [00:14<01:03,  6.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  18%|█▊        | 89/500 [00:14<01:02,  6.55it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  18%|█▊        | 90/500 [00:14<01:04,  6.34it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  18%|█▊        | 91/500 [00:14<01:03,  6.39it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  18%|█▊        | 92/500 [00:14<01:03,  6.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  19%|█▊        | 93/500 [00:14<01:03,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  19%|█▉        | 94/500 [00:15<01:01,  6.55it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  19%|█▉        | 95/500 [00:15<01:01,  6.58it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  19%|█▉        | 96/500 [00:15<01:01,  6.54it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  19%|█▉        | 97/500 [00:15<01:01,  6.55it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  20%|█▉        | 98/500 [00:15<01:02,  6.40it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  20%|█▉        | 99/500 [00:15<01:02,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  20%|██        | 100/500 [00:15<01:01,  6.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  20%|██        | 101/500 [00:16<01:01,  6.52it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  20%|██        | 102/500 [00:16<01:01,  6.52it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  21%|██        | 103/500 [00:16<01:01,  6.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  21%|██        | 104/500 [00:16<01:00,  6.53it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  21%|██        | 105/500 [00:16<01:01,  6.42it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  21%|██        | 106/500 [00:16<01:01,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  21%|██▏       | 107/500 [00:17<01:01,  6.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  22%|██▏       | 108/500 [00:17<01:02,  6.24it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  22%|██▏       | 109/500 [00:17<01:01,  6.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  22%|██▏       | 110/500 [00:17<01:00,  6.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  22%|██▏       | 111/500 [00:17<00:59,  6.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  22%|██▏       | 112/500 [00:17<00:59,  6.55it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  23%|██▎       | 113/500 [00:17<00:59,  6.48it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  23%|██▎       | 114/500 [00:18<01:00,  6.38it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  23%|██▎       | 115/500 [00:18<00:59,  6.51it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  23%|██▎       | 116/500 [00:18<00:58,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  23%|██▎       | 117/500 [00:18<00:59,  6.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  24%|██▎       | 118/500 [00:18<01:01,  6.23it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  24%|██▍       | 119/500 [00:18<00:59,  6.38it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  24%|██▍       | 120/500 [00:19<00:59,  6.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  24%|██▍       | 121/500 [00:19<00:58,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  24%|██▍       | 122/500 [00:19<00:58,  6.50it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  25%|██▍       | 123/500 [00:19<00:59,  6.34it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  25%|██▍       | 124/500 [00:19<00:58,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  25%|██▌       | 125/500 [00:19<00:59,  6.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  25%|██▌       | 126/500 [00:19<00:59,  6.24it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  25%|██▌       | 127/500 [00:20<00:58,  6.40it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  26%|██▌       | 128/500 [00:20<00:56,  6.58it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  26%|██▌       | 129/500 [00:20<00:56,  6.59it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  26%|██▌       | 130/500 [00:20<00:55,  6.65it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  26%|██▌       | 131/500 [00:20<00:55,  6.65it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  26%|██▋       | 132/500 [00:20<00:55,  6.62it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  27%|██▋       | 133/500 [00:21<00:55,  6.67it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  27%|██▋       | 134/500 [00:21<00:54,  6.66it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  27%|██▋       | 135/500 [00:21<00:55,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  27%|██▋       | 136/500 [00:21<00:55,  6.55it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  27%|██▋       | 137/500 [00:21<00:55,  6.57it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  28%|██▊       | 138/500 [00:21<00:55,  6.56it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  28%|██▊       | 139/500 [00:21<00:54,  6.62it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  28%|██▊       | 140/500 [00:22<00:53,  6.68it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  28%|██▊       | 141/500 [00:22<00:53,  6.68it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  28%|██▊       | 142/500 [00:22<00:53,  6.75it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  29%|██▊       | 143/500 [00:22<00:53,  6.65it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  29%|██▉       | 144/500 [00:22<00:52,  6.75it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  29%|██▉       | 145/500 [00:22<00:52,  6.79it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  29%|██▉       | 146/500 [00:22<00:52,  6.80it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  29%|██▉       | 147/500 [00:23<00:51,  6.79it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  30%|██▉       | 148/500 [00:23<00:51,  6.86it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  30%|██▉       | 149/500 [00:23<00:51,  6.76it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  30%|███       | 150/500 [00:23<00:52,  6.68it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  30%|███       | 151/500 [00:23<00:51,  6.72it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  30%|███       | 152/500 [00:23<00:52,  6.67it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  31%|███       | 153/500 [00:24<00:52,  6.66it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  31%|███       | 154/500 [00:24<00:52,  6.64it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  31%|███       | 155/500 [00:24<00:52,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  31%|███       | 156/500 [00:24<00:53,  6.48it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  31%|███▏      | 157/500 [00:24<00:52,  6.52it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  32%|███▏      | 158/500 [00:24<00:51,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  32%|███▏      | 159/500 [00:24<00:51,  6.62it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  32%|███▏      | 160/500 [00:25<00:51,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  32%|███▏      | 161/500 [00:25<00:50,  6.71it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  32%|███▏      | 162/500 [00:25<00:50,  6.69it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  33%|███▎      | 163/500 [00:25<00:52,  6.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  33%|███▎      | 164/500 [00:25<00:51,  6.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  33%|███▎      | 165/500 [00:25<00:50,  6.62it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  33%|███▎      | 166/500 [00:26<00:54,  6.13it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  33%|███▎      | 167/500 [00:26<00:53,  6.18it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  34%|███▎      | 168/500 [00:26<00:51,  6.39it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  34%|███▍      | 169/500 [00:26<00:51,  6.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  34%|███▍      | 170/500 [00:26<00:50,  6.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  34%|███▍      | 171/500 [00:26<00:52,  6.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  34%|███▍      | 172/500 [00:26<00:52,  6.24it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  35%|███▍      | 173/500 [00:27<00:51,  6.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  35%|███▍      | 174/500 [00:27<00:52,  6.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  35%|███▌      | 175/500 [00:27<00:51,  6.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  35%|███▌      | 176/500 [00:27<00:51,  6.28it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  35%|███▌      | 177/500 [00:27<00:51,  6.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  36%|███▌      | 178/500 [00:27<00:50,  6.36it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  36%|███▌      | 179/500 [00:28<00:51,  6.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  36%|███▌      | 180/500 [00:28<00:49,  6.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  36%|███▌      | 181/500 [00:28<00:49,  6.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  36%|███▋      | 182/500 [00:28<00:48,  6.56it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  37%|███▋      | 183/500 [00:28<00:48,  6.57it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  37%|███▋      | 184/500 [00:28<00:47,  6.65it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  37%|███▋      | 185/500 [00:28<00:47,  6.60it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  37%|███▋      | 186/500 [00:29<00:47,  6.59it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  37%|███▋      | 187/500 [00:29<00:48,  6.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  38%|███▊      | 188/500 [00:29<00:47,  6.56it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  38%|███▊      | 189/500 [00:29<00:47,  6.60it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  38%|███▊      | 190/500 [00:29<00:47,  6.54it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  38%|███▊      | 191/500 [00:29<00:47,  6.54it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  38%|███▊      | 192/500 [00:30<00:46,  6.57it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  39%|███▊      | 193/500 [00:30<00:46,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  39%|███▉      | 194/500 [00:30<00:45,  6.71it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  39%|███▉      | 195/500 [00:30<00:46,  6.60it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  39%|███▉      | 196/500 [00:30<00:45,  6.63it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  39%|███▉      | 197/500 [00:30<00:45,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  40%|███▉      | 198/500 [00:30<00:45,  6.63it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  40%|███▉      | 199/500 [00:31<00:45,  6.58it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  40%|████      | 200/500 [00:31<00:45,  6.66it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  40%|████      | 201/500 [00:31<00:45,  6.57it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  40%|████      | 202/500 [00:31<00:46,  6.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  41%|████      | 203/500 [00:31<00:46,  6.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  41%|████      | 204/500 [00:31<00:46,  6.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  41%|████      | 205/500 [00:32<00:45,  6.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  41%|████      | 206/500 [00:32<00:44,  6.56it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  41%|████▏     | 207/500 [00:32<00:44,  6.62it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  42%|████▏     | 208/500 [00:32<00:44,  6.59it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  42%|████▏     | 209/500 [00:32<00:44,  6.61it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# zero-shot classification:  42%|████▏     | 210/500 [00:32<00:43,  6.62it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ...
# few-shot classification:  87%|████████▋ | 433/500 [01:19<00:12,  5.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  87%|████████▋ | 434/500 [01:19<00:12,  5.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  87%|████████▋ | 435/500 [01:19<00:11,  5.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  87%|████████▋ | 436/500 [01:20<00:11,  5.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  87%|████████▋ | 437/500 [01:20<00:11,  5.50it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  88%|████████▊ | 438/500 [01:20<00:11,  5.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  88%|████████▊ | 439/500 [01:20<00:11,  5.36it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  88%|████████▊ | 440/500 [01:20<00:11,  5.42it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  88%|████████▊ | 441/500 [01:21<00:10,  5.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  88%|████████▊ | 442/500 [01:21<00:10,  5.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  89%|████████▊ | 443/500 [01:21<00:10,  5.34it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  89%|████████▉ | 444/500 [01:21<00:10,  5.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  89%|████████▉ | 445/500 [01:21<00:10,  5.40it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  89%|████████▉ | 446/500 [01:21<00:10,  5.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  89%|████████▉ | 447/500 [01:22<00:09,  5.38it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  90%|████████▉ | 448/500 [01:22<00:09,  5.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  90%|████████▉ | 449/500 [01:22<00:09,  5.35it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  90%|█████████ | 450/500 [01:22<00:09,  5.40it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  90%|█████████ | 451/500 [01:22<00:09,  5.39it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  90%|█████████ | 452/500 [01:23<00:08,  5.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  91%|█████████ | 453/500 [01:23<00:08,  5.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  91%|█████████ | 454/500 [01:23<00:08,  5.27it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  91%|█████████ | 455/500 [01:23<00:08,  5.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  91%|█████████ | 456/500 [01:23<00:08,  5.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  91%|█████████▏| 457/500 [01:23<00:07,  5.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  92%|█████████▏| 458/500 [01:24<00:07,  5.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  92%|█████████▏| 459/500 [01:24<00:07,  5.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  92%|█████████▏| 460/500 [01:24<00:07,  5.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  92%|█████████▏| 461/500 [01:24<00:07,  5.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  92%|█████████▏| 462/500 [01:24<00:06,  5.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  93%|█████████▎| 463/500 [01:25<00:06,  5.40it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  93%|█████████▎| 464/500 [01:25<00:06,  5.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  93%|█████████▎| 465/500 [01:25<00:06,  5.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  93%|█████████▎| 466/500 [01:25<00:06,  5.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  93%|█████████▎| 467/500 [01:25<00:06,  5.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  94%|█████████▎| 468/500 [01:26<00:05,  5.38it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  94%|█████████▍| 469/500 [01:26<00:05,  5.32it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  94%|█████████▍| 470/500 [01:26<00:05,  5.36it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  94%|█████████▍| 471/500 [01:26<00:05,  5.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  94%|█████████▍| 472/500 [01:26<00:05,  5.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  95%|█████████▍| 473/500 [01:26<00:04,  5.40it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  95%|█████████▍| 474/500 [01:27<00:04,  5.42it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  95%|█████████▌| 475/500 [01:27<00:04,  5.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  95%|█████████▌| 476/500 [01:27<00:04,  5.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  95%|█████████▌| 477/500 [01:27<00:04,  5.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  96%|█████████▌| 478/500 [01:27<00:04,  5.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  96%|█████████▌| 479/500 [01:28<00:03,  5.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  96%|█████████▌| 480/500 [01:28<00:03,  5.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  96%|█████████▌| 481/500 [01:28<00:03,  5.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  96%|█████████▋| 482/500 [01:28<00:03,  5.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  97%|█████████▋| 483/500 [01:28<00:03,  5.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  97%|█████████▋| 484/500 [01:28<00:02,  5.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  97%|█████████▋| 485/500 [01:29<00:02,  5.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  97%|█████████▋| 486/500 [01:29<00:02,  5.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  97%|█████████▋| 487/500 [01:29<00:02,  5.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  98%|█████████▊| 488/500 [01:29<00:02,  5.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  98%|█████████▊| 489/500 [01:29<00:02,  5.49it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  98%|█████████▊| 490/500 [01:30<00:01,  5.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  98%|█████████▊| 491/500 [01:30<00:01,  5.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  98%|█████████▊| 492/500 [01:30<00:01,  5.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  99%|█████████▊| 493/500 [01:30<00:01,  5.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  99%|█████████▉| 494/500 [01:30<00:01,  5.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  99%|█████████▉| 495/500 [01:30<00:00,  5.46it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  99%|█████████▉| 496/500 [01:31<00:00,  5.45it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification:  99%|█████████▉| 497/500 [01:31<00:00,  5.42it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification: 100%|█████████▉| 498/500 [01:31<00:00,  5.47it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification: 100%|█████████▉| 499/500 [01:31<00:00,  5.41it/s]The following generation flags are not valid and may be ignored: ['temperature', 'early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# few-shot classification: 100%|██████████| 500/500 [01:31<00:00,  5.44it/s]
# Accuracy (few-shot): 0.7180
#
# Примеры (test) с предсказаниями (true -> pred) для few-shot:
# 1. [Business] → [Business]  |  Fears for T N pension after talks Unions representing worker...
# 2. [Sci/Tech] → [Science ---]  |  The Race is On: Second Private Team Sets Launch Date for Hum...
# 3. [Sci/Tech] → [Science ---]  |  Ky. Company Wins Grant to Study Peptides (AP) AP - A company...
# 4. [Sci/Tech] → [World]  |  Prediction Unit Helps Forecast Wildfires (AP) AP - It's bare...
# 5. [Sci/Tech] → [World]  |  Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern Ca...

# %% [markdown]
# # Выводы:
#
# 1. Видим, что наибольная accuracy получилась для zero-shot. Это происходит по нескольким причинам. При few-shot в промпте сразу несколько примеров, и итоговая длина может превышать ограничение. Из-за этого промт усекается, и модель не видит всех примеров, что снижает качество вывода. Когда в подсказке слишком много примеров, модель путается между ними и новым текстом, особенно в T5-small, где пропускная способность ограничена.
#
# 2. Заметим, что для категории Sci/Tech модель выдаёт Science. Это происходит потому, что модель не возвращает точные строки Sci/Tech, а генерирует ближайшее по смыслу слово (в этом случае Science). При попытке поиска точного совпадения с AG_LABELS Sci/Tech нижний регистр и формат не совпадают, поэтому такие ответы считаются некорректными. Но в реальности видно, что модель улавливает смысл новости.
#
# 3. T5-small не обладает достаточной емкостью для запоминания сразу нескольких примеров и сложных инструкций. Zero-shot промт короче, и модель точнее фокусируется на инструкции. Если примеры few-shot случайно содержат мало репрезентативных статей для каждой категории (например, три примера с большими перекосами), модель плохо обобщает на новые статьи.
#
# 4. Идейно, можно улучшить качество вот так:
#
#    * Можно сократить кол-во примеров до 1–2 (one-shot или two-shot).
#    * Можем явно указывать точный формат меток в описании задачи.
#    * Возможно нужна более крупная модель, чтобы увеличить емкость и глубже обрабатывать контекст few-shot.
#    * Еще мб помогло бы выбрать не случайные статьи, а какие-то тексты по всем 4 категориям.
#
# 5. Zero-shot промт короче и понятнее, поэтому T5-small лучше справляется без примеров. One-shot уже добавляет один образец, и производительность немного падает. Few-shot даёт слишком длинный, частично усечённый промт, что ухудшает качество.
#
# 6. То есть, для совсем небольших моделей есть смысл брать one- или two-shot, а для few-shot использовать модели с большим количеством параметров.
